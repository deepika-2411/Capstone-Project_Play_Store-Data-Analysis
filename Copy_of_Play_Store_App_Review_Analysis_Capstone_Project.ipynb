# %% [markdown]
# <a href="https://colab.research.google.com/github/deepika-2411/Capstone-Project_Play_Store-Data-Analysis/blob/main/Copy_of_Play_Store_App_Review_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>
#
# # 1.Importing the required libraries
# # 2. Fetch the data set from given format Doing some operation on the data set
# # 3.Data filtering and store in it proper format(sort column,drop null value,drop some column,change in required data type)
# # 4.Some important observation findout some relation in dataset through the graph

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
playstore_directory='/content/drive/MyDrive/Colab Notebooks/excel/ Play Store Data.csv'
playapp_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/excel/ Play Store Data.csv')
playapp_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
# drop the null value from Rating column
playapp_df.dropna(axis=0, how='all', subset=['Rating'], inplace=True)
playapp_df
# drop the row because of invalid data
playapp_df.drop([10472],axis=0,inplace=True)
#sort value from Rating column
sort_df=playapp_df.sort_values(["Rating"], ascending=False)
sort_df
# Out:
#                                                     App            Category  \
# 9056                        Santa's Monster Shootout DX                GAME
# 8395                                              DG TV  NEWS_AND_MAGAZINES
# 8493                                PK and DK Audio App              FAMILY
# 6330                          HON. B.J. ACS COLLEGE ALE              FAMILY
# 6342                                           BJ Foods            BUSINESS
# ...                                                 ...                 ...
# 7806                                        CR Magazine            BUSINESS
# 10591  Lottery Ticket Checker - Florida Results & Lotto               TOOLS
# 7427                                     CJ DVD Rentals       COMMUNICATION
# 7926                               Tech CU Card Manager             FINANCE
# 4127                                  Speech Therapy: F              FAMILY
#
#        Rating Reviews  Size Installs  Type  Price Content Rating  \
# 9056      5.0       4   33M      50+  Paid  $1.99           Teen
# 8395      5.0       3  5.7M     100+  Free      0       Everyone
# 8493      5.0       2  3.9M     100+  Free      0       Everyone
# 6330      5.0       3  1.8M     100+  Free      0     Mature 17+
# 6342      5.0       3  1.5M      10+  Free      0       Everyone
# ...       ...     ...   ...      ...   ...    ...            ...
# 7806      1.0       1  7.8M     100+  Free      0       Everyone
# 10591     1.0       3   41M     500+  Free      0       Everyone
# 7427      1.0       5   13M     100+  Free      0       Everyone
# 7926      1.0       2  7.2M   1,000+  Free      0       Everyone
# 4127      1.0       1   16M      10+  Paid  $2.99       Everyone
#
#                  Genres       Last Updated Current Ver   Android Ver
# 9056             Action    August 15, 2013        1.05    2.2 and up
# 8395   News & Magazines       May 26, 2018         1.2    4.1 and up
# 8493      Entertainment   October 25, 2017       5.1.4    4.1 and up
# 6330          Education  December 26, 2016         3.1    4.3 and up
# 6342           Business   February 7, 2018         2.7    4.1 and up
# ...                 ...                ...         ...           ...
# 7806           Business      July 23, 2014       2.4.2  2.3.3 and up
# 10591             Tools  December 12, 2017         1.0    4.2 and up
# 7427      Communication    October 6, 2017         1.0    4.1 and up
# 7926            Finance      July 25, 2017       1.0.1    4.0 and up
# 4127          Education    October 7, 2016         1.0  2.3.3 and up
#
# [9366 rows x 13 columns]

# %% [markdown]
# # Find the top 5 Food and Drink category from Category column based on Rating

# %%
# Find the Food and Drink category from Category column
food_app_df=sort_df[sort_df['Category'] == 'FOOD_AND_DRINK']
food_app_df
# Out:
#                                             App        Category  Rating  \
# 6646                          Bar-B-Q Rib House  FOOD_AND_DRINK     5.0
# 5776       Food-Aw - Order Food Online in Aruba  FOOD_AND_DRINK     5.0
# 6650                            Bar-B-Q Recipes  FOOD_AND_DRINK     4.8
# 1212  SarashpazPapion (Cooking with Chef Bowls)  FOOD_AND_DRINK     4.8
# 1184             Pastry & Cooking (Without Net)  FOOD_AND_DRINK     4.7
# ...                                         ...             ...     ...
# 1190                                Pyaterochka  FOOD_AND_DRINK     3.1
# 8737                                     Arby's  FOOD_AND_DRINK     3.1
# 3961                                     B.GOOD  FOOD_AND_DRINK     2.9
# 4522                       Q-Tech Companion App  FOOD_AND_DRINK     1.8
# 5736                            A&W Restaurants  FOOD_AND_DRINK     1.7
#
#      Reviews                Size    Installs  Type Price Content Rating  \
# 6646       2                 33M         50+  Free     0       Everyone
# 5776       1                 24M        100+  Free     0       Everyone
# 6650      18                3.5M      5,000+  Free     0       Everyone
# 1212    1250                 13M     50,000+  Free     0       Everyone
# 1184    6118  Varies with device  1,000,000+  Free     0       Everyone
# ...      ...                 ...         ...   ...   ...            ...
# 1190    8412  Varies with device  1,000,000+  Free     0       Everyone
# 8737     194                 26M    100,000+  Free     0       Everyone
# 3961     155                 20M     10,000+  Free     0       Everyone
# 4522      17                3.1M     10,000+  Free     0       Everyone
# 5736      14                 13M      1,000+  Free     0       Everyone
#
#             Genres     Last Updated         Current Ver         Android Ver
# 6646  Food & Drink    March 8, 2018                 0.8        2.3.3 and up
# 5776  Food & Drink    April 5, 2018                  10          4.1 and up
# 6650  Food & Drink  August 15, 2016                 1.0          4.0 and up
# 1212  Food & Drink    July 28, 2018               3.2.7          4.1 and up
# 1184  Food & Drink     July 7, 2018  Varies with device  Varies with device
# ...            ...              ...                 ...                 ...
# 1190  Food & Drink    July 19, 2018  Varies with device          4.4 and up
# 8737  Food & Drink    July 12, 2018               1.3.1          4.4 and up
# 3961  Food & Drink    April 4, 2018             4.94.19          4.1 and up
# 4522  Food & Drink    March 8, 2017               1.6.3          4.4 and up
# 5736  Food & Drink     June 6, 2018               2.7.0          4.1 and up
#
# [109 rows x 13 columns]

# %%
# Drop some column from Dataset and find best Food and Drink app based on Rating
df_new_column=food_app_df.drop(['Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated','Reviews','Size', 'Current Ver', 'Android Ver'],axis=1).head().reset_index(drop=True)
df_new_column
# Out:
#                                          App        Category  Rating
# 0                          Bar-B-Q Rib House  FOOD_AND_DRINK     5.0
# 1       Food-Aw - Order Food Online in Aruba  FOOD_AND_DRINK     5.0
# 2                            Bar-B-Q Recipes  FOOD_AND_DRINK     4.8
# 3  SarashpazPapion (Cooking with Chef Bowls)  FOOD_AND_DRINK     4.8
# 4             Pastry & Cooking (Without Net)  FOOD_AND_DRINK     4.7

# %% [markdown]
# # Find the total number of content rating provided by teen user(categorywise) and plot the bar graph

# %%
# find the all teen user from content rating
teen_df=playapp_df[playapp_df['Content Rating'] == 'Teen']
teen_df
# Out:
#                                                  App             Category  \
# 3                              Sketch - Draw & Paint       ART_AND_DESIGN
# 12                    Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 34                                   I Creative Idea       ART_AND_DESIGN
# 72     Android Auto - Maps, Media, Messaging & Voice    AUTO_AND_VEHICLES
# 112    Selfie Camera Photo Editor & Filter & Sticker               BEAUTY
# ...                                              ...                  ...
# 10803                   Fatal Raid - No.1 Mobile FPS                 GAME
# 10804                                   Poker Pro.Fr                 GAME
# 10814                           FR: My Secret Pets!                FAMILY
# 10819                                      Fanfic-FR  BOOKS_AND_REFERENCE
# 10820                                Fr. Daoud Lamei               FAMILY
#
#        Rating Reviews  Size     Installs  Type Price Content Rating  \
# 3         4.5  215644   25M  50,000,000+  Free     0           Teen
# 12        4.2   44829   20M  10,000,000+  Free     0           Teen
# 34        4.7     353  4.2M      10,000+  Free     0           Teen
# 72        4.2  271920   16M  10,000,000+  Free     0           Teen
# 112       4.1     187   30M      50,000+  Free     0           Teen
# ...       ...     ...   ...          ...   ...   ...            ...
# 10803     4.3   56496   81M   1,000,000+  Free     0           Teen
# 10804     4.2    5442   17M     100,000+  Free     0           Teen
# 10814     4.0     785   31M      50,000+  Free     0           Teen
# 10819     3.3      52  3.6M       5,000+  Free     0           Teen
# 10820     5.0      22  8.6M       1,000+  Free     0           Teen
#
#                   Genres    Last Updated         Current Ver   Android Ver
# 3           Art & Design    June 8, 2018  Varies with device    4.2 and up
# 12          Art & Design   April 2, 2018                 3.8    4.1 and up
# 34          Art & Design  April 27, 2018                 1.6    4.1 and up
# 72       Auto & Vehicles   July 11, 2018  Varies with device    5.0 and up
# 112               Beauty   July 24, 2018               3.0.1  4.0.3 and up
# ...                  ...             ...                 ...           ...
# 10803             Action  August 7, 2018             1.5.447    4.0 and up
# 10804               Card    May 22, 2018               4.1.3    2.3 and up
# 10814      Entertainment    June 3, 2015               1.3.1    3.0 and up
# 10819  Books & Reference  August 5, 2017               0.3.4    4.1 and up
# 10820          Education   June 27, 2018               3.8.0    4.1 and up
#
# [1084 rows x 13 columns]

# %%
# finf the total no. of content rating provided by teen (categorywise) 
count_category = teen_df.groupby(["Category"])['Content Rating'].count()
count_category
# Out:
# Category
# ART_AND_DESIGN           3
# AUTO_AND_VEHICLES        1
# BEAUTY                   2
# BOOKS_AND_REFERENCE     20
# BUSINESS                 4
# COMICS                  22
# COMMUNICATION           24
# DATING                   6
# EDUCATION                1
# ENTERTAINMENT           96
# EVENTS                   7
# FAMILY                 242
# FINANCE                  4
# FOOD_AND_DRINK           7
# GAME                   324
# HEALTH_AND_FITNESS      17
# HOUSE_AND_HOME           2
# LIFESTYLE               18
# MAPS_AND_NAVIGATION      2
# MEDICAL                  3
# NEWS_AND_MAGAZINES      31
# PARENTING                1
# PERSONALIZATION         28
# PHOTOGRAPHY             12
# PRODUCTIVITY             2
# SHOPPING                48
# SOCIAL                 106
# SPORTS                  15
# TOOLS                    5
# TRAVEL_AND_LOCAL         5
# VIDEO_PLAYERS           24
# WEATHER                  2
# Name: Content Rating, dtype: int64

# %%
#plot the bar graph
count_category.plot(kind='bar',color='maroon',figsize=(15,8))
plt.title('Total no. of content rating provided by teen')
plt.ylabel('total no. of content rating (teen)')
plt.xlabel('Category')
# Out:
# Text(0.5, 0, 'Category')

# %% [markdown]
# # Find the Revenue using installs and price value

# %%
# Change the string value into float in price column
a= playapp_df[playapp_df['App'] == playapp_df['Price']]
playapp_df.drop(a.index[:],axis=0,inplace=True)
playapp_df['Price']=playapp_df['Price'].replace('4.1 and up',0).replace('Everyone',0).apply(lambda x:float(x.replace('$','')))

# %%
#playapp_df.info()
# find all price which is greater thean 0
daf_1=playapp_df['Price'].values >0
daf_2=playapp_df.loc[daf_1]
daf_2
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 290    TurboScan: scan documents and receipts in PDF            BUSINESS
# 291                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# ...                                              ...                 ...
# 10690                                       FO Bixby     PERSONALIZATION
# 10697                                        Mu.F.O.                GAME
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
#
#        Rating Reviews                Size  Installs  Type  Price  \
# 234       4.7   11442                6.8M  100,000+  Paid   4.99
# 235       4.8   10295                 39M  100,000+  Paid   4.99
# 290       4.7   11442                6.8M  100,000+  Paid   4.99
# 291       4.8   10295                 39M  100,000+  Paid   4.99
# 427       4.0   18247  Varies with device  100,000+  Paid   3.99
# ...       ...     ...                 ...       ...   ...    ...
# 10690     5.0       5                861k      100+  Paid   0.99
# 10697     5.0       2                 16M        1+  Paid   0.99
# 10760     4.4      35                2.4M    1,000+  Paid   7.99
# 10782     3.8     252                 11M   10,000+  Paid  16.99
# 10785     4.2    1405                9.5M   10,000+  Paid   1.20
#
#       Content Rating            Genres       Last Updated  Current Ver  \
# 234         Everyone          Business     March 25, 2018        1.5.2
# 235         Everyone          Business     April 11, 2017        3.4.6
# 290         Everyone          Business     March 25, 2018        1.5.2
# 291         Everyone          Business     April 11, 2017        3.4.6
# 427         Everyone     Communication       July 5, 2018  7.5.3.20547
# ...              ...               ...                ...          ...
# 10690       Everyone   Personalization     April 25, 2018          0.2
# 10697       Everyone            Arcade      March 3, 2017          1.0
# 10760       Everyone  Health & Fitness     August 8, 2018        1.9.3
# 10782           Teen            Action  February 27, 2015         2.22
# 10785       Everyone            Puzzle       June 5, 2018          2.7
#
#       Android Ver
# 234    4.0 and up
# 235    3.0 and up
# 290    4.0 and up
# 291    3.0 and up
# 427    4.1 and up
# ...           ...
# 10690  7.0 and up
# 10697  2.3 and up
# 10760  4.2 and up
# 10782  5.0 and up
# 10785  2.3 and up
#
# [647 rows x 13 columns]

# %%
# Change the stinrg value into float in installs column
b= playapp_df[playapp_df['App'] == playapp_df['Installs']]
playapp_df.drop(b.index[:],axis=0,inplace=True)

playapp_df['Installs']=playapp_df['Installs'].apply(lambda x:float(x[0:(len(x)-1)].replace(',','')))
playapp_df['Installs']
# Out:
# 0           10000.0
# 1          500000.0
# 2         5000000.0
# 3        50000000.0
# 4          100000.0
#             ...
# 10834         500.0
# 10836        5000.0
# 10837         100.0
# 10839        1000.0
# 10840    10000000.0
# Name: Installs, Length: 9366, dtype: float64

# %%
# Create new Revenue column using price and installs column
playapp_df['Revenue']=playapp_df['Price']*playapp_df['Installs']
# sorting the value
sort_df_1=playapp_df.sort_values(["Revenue"], ascending=False)
sort_df_1
# Out:
#                                                  App   Category  Rating  \
# 2241                                       Minecraft     FAMILY     4.5
# 4347                                       Minecraft     FAMILY     4.5
# 5351                                       I am rich  LIFESTYLE     3.8
# 5356                               I Am Rich Premium    FINANCE     4.1
# 4034                                   Hitman Sniper       GAME     4.6
# ...                                              ...        ...     ...
# 3306                                   Calculator ++      TOOLS     4.6
# 3305                                  Unit Converter      TOOLS     4.5
# 3304                             Graphing Calculator      TOOLS     3.9
# 3303                  Calculator with Percent (Free)      TOOLS     4.8
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#        Reviews                Size    Installs  Type   Price Content Rating  \
# 2241   2376564  Varies with device  10000000.0  Paid    6.99   Everyone 10+
# 4347   2375336  Varies with device  10000000.0  Paid    6.99   Everyone 10+
# 5351      3547                1.8M    100000.0  Paid  399.99       Everyone
# 5356      1867                4.7M     50000.0  Paid  399.99       Everyone
# 4034    408292                 29M  10000000.0  Paid    0.99     Mature 17+
# ...        ...                 ...         ...   ...     ...            ...
# 3306     33509                3.6M   1000000.0  Free    0.00       Everyone
# 3305     85387                5.4M   1000000.0  Free    0.00       Everyone
# 3304     12388                5.3M   1000000.0  Free    0.00       Everyone
# 3303     48211                7.4M   1000000.0  Free    0.00       Everyone
# 10840   398307                 19M  10000000.0  Free    0.00       Everyone
#
#                           Genres       Last Updated         Current Ver  \
# 2241   Arcade;Action & Adventure      July 24, 2018             1.5.2.1
# 4347   Arcade;Action & Adventure      July 24, 2018             1.5.2.1
# 5351                   Lifestyle   January 12, 2018                 2.0
# 5356                     Finance  November 12, 2017                 1.6
# 4034                      Action      July 12, 2018          1.7.110758
# ...                          ...                ...                 ...
# 3306                       Tools       May 12, 2018               2.2.7
# 3305                       Tools       July 3, 2018              2.1.54
# 3304                       Tools      April 1, 2016                1.17
# 3303                       Tools  November 18, 2017                32.1
# 10840                  Lifestyle      July 25, 2018  Varies with device
#
#               Android Ver     Revenue
# 2241   Varies with device  69900000.0
# 4347   Varies with device  69900000.0
# 5351         4.0.3 and up  39999000.0
# 5356           4.0 and up  19999500.0
# 4034           4.1 and up   9900000.0
# ...                   ...         ...
# 3306           4.4 and up         0.0
# 3305           4.0 and up         0.0
# 3304           2.3 and up         0.0
# 3303           4.1 and up         0.0
# 10840  Varies with device         0.0
#
# [9366 rows x 14 columns]

# %% [markdown]
# # Another CSV file

# %%
#Read another CSV file
playapp_df_1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/excel/ User Reviews.csv')
#playapp_df_1.set_index('App',inplace=True)
playapp_df_1
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# 64292                                                NaN       NaN
# 64293                                                NaN       NaN
# 64294                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                    1.00                0.533333
# 1                    0.25                0.288462
# 2                     NaN                     NaN
# 3                    0.40                0.875000
# 4                    1.00                0.300000
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [64295 rows x 5 columns]

# %% [markdown]
# # Find the avarage number of words used in translated review

# %%
# Remove null value from Translated_Review column
playapp_df_1.dropna(axis=0, how='all', subset=['Translated_Review'], inplace=True)
playapp_df_1
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# 64222  Most ads older many agents ..not much owner po...  Positive
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 3                0.400000                0.875000
# 4                1.000000                0.300000
# 5                1.000000                0.300000
# ...                   ...                     ...
# 64222            0.173333                0.486667
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000
#
# [37427 rows x 5 columns]

# %%
# Fetching the Translated_Review column from the dataset
new_df=playapp_df_1.iloc[:,1:2]
#playapp_df_1.drop(new_df.index[:],axis=0,inplace=True)
new_df
# Out:
#                                        Translated_Review
# 0      I like eat delicious food. That's I'm cooking ...
# 1        This help eating healthy exercise regular basis
# 3             Works great especially going grocery store
# 4                                           Best idea us
# 5                                               Best way
# ...                                                  ...
# 64222  Most ads older many agents ..not much owner po...
# 64223  If photos posted portal load, fit purpose. I'm...
# 64226  Dumb app, I wanted post property rent give opt...
# 64227  I property business got link SMS happy perform...
# 64230  Useless app, I searched flats kondapur, Hydera...
#
# [37427 rows x 1 columns]

# %%
# Find the avarage number of words used in Translated_Review column
count=0
for item in new_df['Translated_Review']:
  count=count+len(item.split())
print("Total number of words in Translated_Review=",count)
print("Avarage number of words used in Translated_Review=",round(count/37427),'words.')
# Out:
# Total number of words in Translated_Review= 686808
# Avarage number of words used in Translated_Review= 18 words.

# %% [markdown]
# # Find the total number different user sentiment from Sentiment column

# %%
# Remove null value from Sentiment column
playapp_df_1.dropna(axis=0, how='all', subset=['Sentiment'], inplace=True)
playapp_df_1
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# 64222  Most ads older many agents ..not much owner po...  Positive
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 3                0.400000                0.875000
# 4                1.000000                0.300000
# 5                1.000000                0.300000
# ...                   ...                     ...
# 64222            0.173333                0.486667
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000
#
# [37427 rows x 5 columns]

# %%
# Find the total number different user sentiment from Sentiment column
count_sentiment = playapp_df_1.groupby(["Sentiment"])["Sentiment"].count()
count_sentiment
# Out:
# Sentiment
# Negative     8271
# Neutral      5158
# Positive    23998
# Name: Sentiment, dtype: int64

# %%
plt.plot(count_sentiment)
plt.title('Different user sentiment')
plt.ylabel('total no. of different user sentiment')
plt.xlabel('Sentiment')
# Out:
# Text(0.5, 0, 'Sentiment')

# %%
# Provide the bar graph of all the application having different user sentiment
from itertools import cycle, islice
my_colors = list(islice(cycle(['b', 'r', 'g']), None, len(playapp_df)))

count_sentiment.plot(kind='bar',stacked=True, color=my_colors)
plt.title('Different user sentiment')
plt.ylabel('total no. of different user sentiment')
plt.xlabel('Sentiment')
# Out:
# Text(0.5, 0, 'Sentiment')

# %%
# merged two csv file
merged_playapp_df = pd.merge(playapp_df, playapp_df_1, how='left',left_on=['App'],right_on='App')
merged_playapp_df
# Out:
#                                                   App             Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                 Coloring book moana       ART_AND_DESIGN
# 2                                 Coloring book moana       ART_AND_DESIGN
# 3                                 Coloring book moana       ART_AND_DESIGN
# 4                                 Coloring book moana       ART_AND_DESIGN
# ...                                               ...                  ...
# 80699                                   FR Calculator               FAMILY
# 80700                                Sya9a Maroc - FR               FAMILY
# 80701                Fr. Mike Schmitz Audio Teachings               FAMILY
# 80702                   The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 80703   iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size    Installs  Type  Price  \
# 0         4.1     159                 19M     10000.0  Free    0.0
# 1         3.9     967                 14M    500000.0  Free    0.0
# 2         3.9     967                 14M    500000.0  Free    0.0
# 3         3.9     967                 14M    500000.0  Free    0.0
# 4         3.9     967                 14M    500000.0  Free    0.0
# ...       ...     ...                 ...         ...   ...    ...
# 80699     4.0       7                2.6M       500.0  Free    0.0
# 80700     4.5      38                 53M      5000.0  Free    0.0
# 80701     5.0       4                3.6M       100.0  Free    0.0
# 80702     4.5     114  Varies with device      1000.0  Free    0.0
# 80703     4.5  398307                 19M  10000000.0  Free    0.0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone  Art & Design;Pretend Play  January 15, 2018
# 3           Everyone  Art & Design;Pretend Play  January 15, 2018
# 4           Everyone  Art & Design;Pretend Play  January 15, 2018
# ...              ...                        ...               ...
# 80699       Everyone                  Education     June 18, 2017
# 80700       Everyone                  Education     July 25, 2017
# 80701       Everyone                  Education      July 6, 2018
# 80702     Mature 17+          Books & Reference  January 19, 2015
# 80703       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver  Revenue  \
# 0                   1.0.0        4.0.3 and up      0.0
# 1                   2.0.0        4.0.3 and up      0.0
# 2                   2.0.0        4.0.3 and up      0.0
# 3                   2.0.0        4.0.3 and up      0.0
# 4                   2.0.0        4.0.3 and up      0.0
# ...                   ...                 ...      ...
# 80699               1.0.0          4.1 and up      0.0
# 80700                1.48          4.1 and up      0.0
# 80701                 1.0          4.1 and up      0.0
# 80702  Varies with device  Varies with device      0.0
# 80703  Varies with device  Varies with device      0.0
#
#                                        Translated_Review Sentiment  \
# 0                                                    NaN       NaN
# 1      A kid's excessive ads. The types ads allowed a...  Negative
# 2                                             It bad >:(  Negative
# 3                                                   like   Neutral
# 4                               I love colors inspyering  Positive
# ...                                                  ...       ...
# 80699                                                NaN       NaN
# 80700                                                NaN       NaN
# 80701                                                NaN       NaN
# 80702                                                NaN       NaN
# 80703                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                     NaN                     NaN
# 1                  -0.250                1.000000
# 2                  -0.725                0.833333
# 3                   0.000                0.000000
# 4                   0.500                0.600000
# ...                   ...                     ...
# 80699                 NaN                     NaN
# 80700                 NaN                     NaN
# 80701                 NaN                     NaN
# 80702                 NaN                     NaN
# 80703                 NaN                     NaN
#
# [80704 rows x 18 columns]

# %% [markdown]
# # Top 5 application having positive: Sentiment Polarity > 0.5, Sentiment subjectivity >0.5 and provide that application category also.

# %%
# remove null value from the Sentiment_polarity column
merged_playapp_df.dropna(axis=0, how='all', subset=['Sentiment_Polarity'], inplace=True)
merged_playapp_df
# Out:
#                                       App        Category  Rating Reviews  \
# 1                     Coloring book moana  ART_AND_DESIGN     3.9     967
# 2                     Coloring book moana  ART_AND_DESIGN     3.9     967
# 3                     Coloring book moana  ART_AND_DESIGN     3.9     967
# 4                     Coloring book moana  ART_AND_DESIGN     3.9     967
# 5                     Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                                   ...             ...     ...     ...
# 80614  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 80615  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 80616  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 80617  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 80618  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
#
#        Size   Installs  Type  Price Content Rating                     Genres  \
# 1       14M   500000.0  Free    0.0       Everyone  Art & Design;Pretend Play
# 2       14M   500000.0  Free    0.0       Everyone  Art & Design;Pretend Play
# 3       14M   500000.0  Free    0.0       Everyone  Art & Design;Pretend Play
# 4       14M   500000.0  Free    0.0       Everyone  Art & Design;Pretend Play
# 5       14M   500000.0  Free    0.0       Everyone  Art & Design;Pretend Play
# ...     ...        ...   ...    ...            ...                        ...
# 80614  4.0M  1000000.0  Free    0.0       Everyone              Communication
# 80615  4.0M  1000000.0  Free    0.0       Everyone              Communication
# 80616  4.0M  1000000.0  Free    0.0       Everyone              Communication
# 80617  4.0M  1000000.0  Free    0.0       Everyone              Communication
# 80618  4.0M  1000000.0  Free    0.0       Everyone              Communication
#
#            Last Updated Current Ver   Android Ver  Revenue  \
# 1      January 15, 2018       2.0.0  4.0.3 and up      0.0
# 2      January 15, 2018       2.0.0  4.0.3 and up      0.0
# 3      January 15, 2018       2.0.0  4.0.3 and up      0.0
# 4      January 15, 2018       2.0.0  4.0.3 and up      0.0
# 5      January 15, 2018       2.0.0  4.0.3 and up      0.0
# ...                 ...         ...           ...      ...
# 80614      July 6, 2018         5.2    5.0 and up      0.0
# 80615      July 6, 2018         5.2    5.0 and up      0.0
# 80616      July 6, 2018         5.2    5.0 and up      0.0
# 80617      July 6, 2018         5.2    5.0 and up      0.0
# 80618      July 6, 2018         5.2    5.0 and up      0.0
#
#                                        Translated_Review Sentiment  \
# 1      A kid's excessive ads. The types ads allowed a...  Negative
# 2                                             It bad >:(  Negative
# 3                                                   like   Neutral
# 4                               I love colors inspyering  Positive
# 5                                                 I hate  Negative
# ...                                                  ...       ...
# 80614  Nice broser slow browsing speed... make 8mbps ...  Positive
# 80615  The thing I found missing simple bookmark draw...  Positive
# 80616  Great Relief unwanted pop ups showing up. What...  Positive
# 80617  Hoped found new go-to; LOVE Firefox PC. Aside ...  Positive
# 80618  Moment I turned YouTube video I got ad. That's...   Neutral
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 1               -0.250000                1.000000
# 2               -0.725000                0.833333
# 3                0.000000                0.000000
# 4                0.500000                0.600000
# 5               -0.800000                0.900000
# ...                   ...                     ...
# 80614            0.100000                0.492308
# 80615            0.225000                0.426786
# 80616            0.650000                0.625000
# 80617            0.345455                0.484848
# 80618            0.000000                0.000000
#
# [72566 rows x 18 columns]

# %%
# find top 5 application having Sentiment_polarity>0.5 and Sentiment_Subjectivity>0.5
df_1=merged_playapp_df[ (merged_playapp_df['Sentiment_Polarity'] > 0.5) & (merged_playapp_df['Sentiment_Subjectivity'] > 0.5)].reset_index(drop=True)
df_1
# Out:
#                                      App        Category  Rating Reviews  \
# 0                    Coloring book moana  ART_AND_DESIGN     3.9     967
# 1                    Coloring book moana  ART_AND_DESIGN     3.9     967
# 2                    Coloring book moana  ART_AND_DESIGN     3.9     967
# 3                    Coloring book moana  ART_AND_DESIGN     3.9     967
# 4                    Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                                  ...             ...     ...     ...
# 8286  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 8287  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 8288  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 8289  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 8290  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
#
#       Size   Installs  Type  Price Content Rating                     Genres  \
# 0      14M   500000.0  Free    0.0       Everyone  Art & Design;Pretend Play
# 1      14M   500000.0  Free    0.0       Everyone  Art & Design;Pretend Play
# 2      14M   500000.0  Free    0.0       Everyone  Art & Design;Pretend Play
# 3      14M   500000.0  Free    0.0       Everyone  Art & Design;Pretend Play
# 4      14M   500000.0  Free    0.0       Everyone  Art & Design;Pretend Play
# ...    ...        ...   ...    ...            ...                        ...
# 8286  4.0M  1000000.0  Free    0.0       Everyone              Communication
# 8287  4.0M  1000000.0  Free    0.0       Everyone              Communication
# 8288  4.0M  1000000.0  Free    0.0       Everyone              Communication
# 8289  4.0M  1000000.0  Free    0.0       Everyone              Communication
# 8290  4.0M  1000000.0  Free    0.0       Everyone              Communication
#
#           Last Updated Current Ver   Android Ver  Revenue  \
# 0     January 15, 2018       2.0.0  4.0.3 and up      0.0
# 1     January 15, 2018       2.0.0  4.0.3 and up      0.0
# 2     January 15, 2018       2.0.0  4.0.3 and up      0.0
# 3     January 15, 2018       2.0.0  4.0.3 and up      0.0
# 4     January 15, 2018       2.0.0  4.0.3 and up      0.0
# ...                ...         ...           ...      ...
# 8286      July 6, 2018         5.2    5.0 and up      0.0
# 8287      July 6, 2018         5.2    5.0 and up      0.0
# 8288      July 6, 2018         5.2    5.0 and up      0.0
# 8289      July 6, 2018         5.2    5.0 and up      0.0
# 8290      July 6, 2018         5.2    5.0 and up      0.0
#
#                                       Translated_Review Sentiment  \
# 0                                            Good great  Positive
# 1                                        This beautiful  Positive
# 2                                               Perfect  Positive
# 3                                            Good great  Positive
# 4                                        This beautiful  Positive
# ...                                                 ...       ...
# 8286  Great Relief unwanted pop ups showing up. What...  Positive
# 8287  Great app! Love addition search page. Can cons...  Positive
# 8288  Best browser... If privacy concern please brow...  Positive
# 8289  Firefox Focus mobile browsers be. It 'feels' f...  Positive
# 8290  Great Relief unwanted pop ups showing up. What...  Positive
#
#       Sentiment_Polarity  Sentiment_Subjectivity
# 0               0.750000                0.675000
# 1               0.850000                1.000000
# 2               1.000000                1.000000
# 3               0.750000                0.675000
# 4               0.850000                1.000000
# ...                  ...                     ...
# 8286            0.650000                0.625000
# 8287            0.550000                0.518750
# 8288            0.535119                0.714286
# 8289            0.600000                0.900000
# 8290            0.650000                0.625000
#
# [8291 rows x 18 columns]

# %%
df_1=merged_playapp_df[ (merged_playapp_df['Sentiment_Polarity'] > 0.5) & (merged_playapp_df['Sentiment_Subjectivity'] > 0.5)].reset_index(drop=True).max()
df_1
# Out:
# App                            Housing-Real Estate & Property
# Category                                              WEATHER
# Rating                                                    4.9
# Reviews                                                  9971
# Size                                       Varies with device
# Installs                                         1000000000.0
# Type                                                     Paid
# Price                                                   29.99
# Content Rating                                           Teen
# Genres                                                Weather
# Last Updated                                September 8, 2017
# Current Ver                           v7.0.7.1.0625.1_06_0629
# Android Ver                                Varies with device
# Revenue                                             2490000.0
# Translated_Review         works well. Love split screen idea!
# Sentiment                                            Positive
# Sentiment_Polarity                                        1.0
# Sentiment_Subjectivity                                    1.0
# dtype: object

# %% [markdown]
# # find the total sum of Sentiment polarity rate categorywise and plot the pie chart based on category

# %%
# find the total sum of Sentiment polarity rate categorywise
df_2=pd.DataFrame(merged_playapp_df.groupby(['Category'])
['Sentiment_Polarity'].count())
df_2
# Out:
#                      Sentiment_Polarity
# Category
# ART_AND_DESIGN                      382
# AUTO_AND_VEHICLES                   289
# BEAUTY                              338
# BOOKS_AND_REFERENCE                 815
# BUSINESS                           2347
# COMICS                               80
# COMMUNICATION                      1949
# DATING                             3198
# EDUCATION                          1694
# ENTERTAINMENT                      2433
# EVENTS                              158
# FAMILY                             5910
# FINANCE                            2009
# FOOD_AND_DRINK                      846
# GAME                              19125
# HEALTH_AND_FITNESS                 4503
# HOUSE_AND_HOME                      697
# LIBRARIES_AND_DEMO                  333
# LIFESTYLE                          1332
# MAPS_AND_NAVIGATION                 192
# MEDICAL                            2172
# NEWS_AND_MAGAZINES                 2204
# PARENTING                           260
# PERSONALIZATION                    1312
# PHOTOGRAPHY                        2480
# PRODUCTIVITY                       3121
# SHOPPING                           2026
# SOCIAL                             1398
# SPORTS                             3504
# TOOLS                              1794
# TRAVEL_AND_LOCAL                   3101
# VIDEO_PLAYERS                       331
# WEATHER                             233

# %%
# Plot the pie chart 
pie_chart=df_2['Sentiment_Polarity'].tolist()
df_2.plot.pie(y='Sentiment_Polarity',title='categorywise total no. of sentiment polarity rate',figsize=(15,20))
