# %% [markdown]
# <a href="https://colab.research.google.com/github/deepika-2411/Capstone-Project_Play_Store-Data-Analysis/blob/main/Copy_of_Play_Store_App_Review_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %%
#Import package
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
playstore_directory='/content/drive/MyDrive/Colab Notebooks/excel/ Play Store Data.csv'
playapp_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/excel/ Play Store Data.csv')
playapp_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
sort_df=playapp_df.sort_values(["Rating"], ascending=False)
sort_df
# Out:
#                                            App             Category  Rating  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame                  1.9    19.0
# 9511                  Ek Bander Ne Kholi Dukan               FAMILY     5.0
# 10166                     FA Player Essentials               SPORTS     5.0
# 7895                Dine In CT - Food Delivery             SHOPPING     5.0
# 5118                          Eternal Light AG               SOCIAL     5.0
# ...                                        ...                  ...     ...
# 10824                                Cardio-FR              MEDICAL     NaN
# 10825                       Naruto & Boruto FR               SOCIAL     NaN
# 10831                 payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                                 FR Forms             BUSINESS     NaN
# 10838                   Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews    Size Installs  Type     Price Content Rating  \
# 10472    3.0M  1,000+     Free     0  Everyone            NaN
# 9511       10    3.0M  10,000+  Free         0       Everyone
# 10166       7     68M     100+  Free         0       Everyone
# 7895        4    1.6M   1,000+  Free         0       Everyone
# 5118       30     13M     100+  Free         0           Teen
# ...       ...     ...      ...   ...       ...            ...
# 10824      67     82M  10,000+  Free         0       Everyone
# 10825       7    7.7M     100+  Free         0           Teen
# 10831      38    9.8M   5,000+  Free         0       Everyone
# 10835       0    9.6M      10+  Free         0       Everyone
# 10838       3    9.5M   1,000+  Free         0       Everyone
#
#                   Genres        Last Updated Current Ver   Android Ver
# 10472  February 11, 2018              1.0.19  4.0 and up           NaN
# 9511       Entertainment       June 26, 2017       1.0.9    4.0 and up
# 10166             Sports       July 23, 2018       1.6.0  4.0.3 and up
# 7895            Shopping        May 16, 2016         1.3    4.0 and up
# 5118              Social        May 19, 2018        1.04  4.0.3 and up
# ...                  ...                 ...         ...           ...
# 10824            Medical       July 31, 2018       2.2.2    4.4 and up
# 10825             Social    February 2, 2018         1.0    4.0 and up
# 10831  Maps & Navigation       June 13, 2018   2.0.148.0    4.0 and up
# 10835           Business  September 29, 2016       1.1.5    4.0 and up
# 10838            Medical    January 20, 2017         1.0    2.2 and up
#
# [10841 rows x 13 columns]

# %%
food_app_df=sort_df[sort_df['Category'] == 'FOOD_AND_DRINK']
food_app_df
# Out:
#                                              App        Category  Rating  \
# 5776        Food-Aw - Order Food Online in Aruba  FOOD_AND_DRINK     5.0
# 6646                           Bar-B-Q Rib House  FOOD_AND_DRINK     5.0
# 1212   SarashpazPapion (Cooking with Chef Bowls)  FOOD_AND_DRINK     4.8
# 6650                             Bar-B-Q Recipes  FOOD_AND_DRINK     4.8
# 6450                    BeyondMenu Food Delivery  FOOD_AND_DRINK     4.7
# ...                                          ...             ...     ...
# 6668                                    BQ Wings  FOOD_AND_DRINK     NaN
# 6670                       Texas Bar-B-Q Rewards  FOOD_AND_DRINK     NaN
# 7445                                 CJ Infinity  FOOD_AND_DRINK     NaN
# 9834                 Recettes Faciles et Rapides  FOOD_AND_DRINK     NaN
# 10347                   Santa Fe Espresso & News  FOOD_AND_DRINK     NaN
#
#       Reviews                Size    Installs  Type Price Content Rating  \
# 5776        1                 24M        100+  Free     0       Everyone
# 6646        2                 33M         50+  Free     0       Everyone
# 1212     1250                 13M     50,000+  Free     0       Everyone
# 6650       18                3.5M      5,000+  Free     0       Everyone
# 6450    51543  Varies with device  1,000,000+  Free     0       Everyone
# ...       ...                 ...         ...   ...   ...            ...
# 6668        1                 13M         50+  Free     0       Everyone
# 6670        0                 14M          5+  Free     0       Everyone
# 7445        0                 16M         10+  Free     0       Everyone
# 9834       95                 12M     50,000+  Free     0       Everyone
# 10347       0                 15M         10+  Free     0       Everyone
#
#              Genres      Last Updated         Current Ver         Android Ver
# 5776   Food & Drink     April 5, 2018                  10          4.1 and up
# 6646   Food & Drink     March 8, 2018                 0.8        2.3.3 and up
# 1212   Food & Drink     July 28, 2018               3.2.7          4.1 and up
# 6650   Food & Drink   August 15, 2016                 1.0          4.0 and up
# 6450   Food & Drink    August 1, 2018  Varies with device  Varies with device
# ...             ...               ...                 ...                 ...
# 6668   Food & Drink     July 17, 2018               2.7.0          4.1 and up
# 6670   Food & Drink    March 28, 2018              2.0.24          4.1 and up
# 7445   Food & Drink   January 5, 2018                 1.1          4.1 and up
# 9834   Food & Drink   January 6, 2018               3.0.1          2.3 and up
# 10347  Food & Drink  October 12, 2017               1.2.2          4.4 and up
#
# [127 rows x 13 columns]

# %%
food_app_df.dropna(axis=0, how='all', subset=['Rating'], inplace=True)
food_app_df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                             App        Category  Rating  \
# 5776       Food-Aw - Order Food Online in Aruba  FOOD_AND_DRINK     5.0
# 6646                          Bar-B-Q Rib House  FOOD_AND_DRINK     5.0
# 1212  SarashpazPapion (Cooking with Chef Bowls)  FOOD_AND_DRINK     4.8
# 6650                            Bar-B-Q Recipes  FOOD_AND_DRINK     4.8
# 6450                   BeyondMenu Food Delivery  FOOD_AND_DRINK     4.7
# ...                                         ...             ...     ...
# 1190                                Pyaterochka  FOOD_AND_DRINK     3.1
# 8737                                     Arby's  FOOD_AND_DRINK     3.1
# 3961                                     B.GOOD  FOOD_AND_DRINK     2.9
# 4522                       Q-Tech Companion App  FOOD_AND_DRINK     1.8
# 5736                            A&W Restaurants  FOOD_AND_DRINK     1.7
#
#      Reviews                Size    Installs  Type Price Content Rating  \
# 5776       1                 24M        100+  Free     0       Everyone
# 6646       2                 33M         50+  Free     0       Everyone
# 1212    1250                 13M     50,000+  Free     0       Everyone
# 6650      18                3.5M      5,000+  Free     0       Everyone
# 6450   51543  Varies with device  1,000,000+  Free     0       Everyone
# ...      ...                 ...         ...   ...   ...            ...
# 1190    8412  Varies with device  1,000,000+  Free     0       Everyone
# 8737     194                 26M    100,000+  Free     0       Everyone
# 3961     155                 20M     10,000+  Free     0       Everyone
# 4522      17                3.1M     10,000+  Free     0       Everyone
# 5736      14                 13M      1,000+  Free     0       Everyone
#
#             Genres     Last Updated         Current Ver         Android Ver
# 5776  Food & Drink    April 5, 2018                  10          4.1 and up
# 6646  Food & Drink    March 8, 2018                 0.8        2.3.3 and up
# 1212  Food & Drink    July 28, 2018               3.2.7          4.1 and up
# 6650  Food & Drink  August 15, 2016                 1.0          4.0 and up
# 6450  Food & Drink   August 1, 2018  Varies with device  Varies with device
# ...            ...              ...                 ...                 ...
# 1190  Food & Drink    July 19, 2018  Varies with device          4.4 and up
# 8737  Food & Drink    July 12, 2018               1.3.1          4.4 and up
# 3961  Food & Drink    April 4, 2018             4.94.19          4.1 and up
# 4522  Food & Drink    March 8, 2017               1.6.3          4.4 and up
# 5736  Food & Drink     June 6, 2018               2.7.0          4.1 and up
#
# [109 rows x 13 columns]

# %%
df_new_column=food_app_df.drop(['Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver'],axis=1).head().reset_index(drop=True)
df_new_column
# Out:
#                                          App        Category  Rating Reviews  \
# 0       Food-Aw - Order Food Online in Aruba  FOOD_AND_DRINK     5.0       1
# 1                          Bar-B-Q Rib House  FOOD_AND_DRINK     5.0       2
# 2  SarashpazPapion (Cooking with Chef Bowls)  FOOD_AND_DRINK     4.8    1250
# 3                            Bar-B-Q Recipes  FOOD_AND_DRINK     4.8      18
# 4                   BeyondMenu Food Delivery  FOOD_AND_DRINK     4.7   51543
#
#                  Size
# 0                 24M
# 1                 33M
# 2                 13M
# 3                3.5M
# 4  Varies with device

# %%
food_app_df.plot(x='Category', y='Rating',style='o')

# %%
playapp_df['year'] = playapp_df['Last Updated'].apply(lambda x:x[-4:])
playapp_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver  year
# 0  4.0.3 and up  2018
# 1  4.0.3 and up  2018
# 2  4.0.3 and up  2018
# 3    4.2 and up  2018
# 4    4.4 and up  2018

# %%
sort_year=playapp_df['year'].loc[[2010,2011,2012,2013,2014,2015,2016,2017,2018],["Last Updated"]] #rows of interest and column of interest
sort_year #show df
#playapp_df
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-15-a66e51e1bdbf> in <module>
# ----> 1 sort_year=playapp_df['year'].loc[[2010,2011,2012,2013,2014,2015,2016,2017,2018],["Last Updated"]] #rows of interest and column of interest
#       2 sort_year #show df
#       3 #playapp_df
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
# -> 1103         self._has_valid_tuple(tup)
#    1104
#    1105         # ugly hack for GH #836
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     749         Check the key for valid keys across my indexer.
#     750         """
# --> 751         self._validate_key_length(key)
#     752         for i, k in enumerate(key):
#     753             try:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_key_length(self, key)
#     790     def _validate_key_length(self, key: Sequence[Any]) -> None:
#     791         if len(key) > self.ndim:
# --> 792             raise IndexingError("Too many indexers")
#     793
#     794     def _getitem_tuple_same_dim(self, tup: tuple):
#
# IndexingError: Too many indexers

# %%
playapp_df_1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/excel/ User Reviews.csv')
#playapp_df_1.set_index('App',inplace=True)
playapp_df_1
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# 64292                                                NaN       NaN
# 64293                                                NaN       NaN
# 64294                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                    1.00                0.533333
# 1                    0.25                0.288462
# 2                     NaN                     NaN
# 3                    0.40                0.875000
# 4                    1.00                0.300000
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [64295 rows x 5 columns]

# %%
playapp_df_1.dropna(axis=0, how='all', subset=['Translated_Review'], inplace=True)
playapp_df_1
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# 64222  Most ads older many agents ..not much owner po...  Positive
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 3                0.400000                0.875000
# 4                1.000000                0.300000
# 5                1.000000                0.300000
# ...                   ...                     ...
# 64222            0.173333                0.486667
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000
#
# [37427 rows x 5 columns]

# %%
new_df=playapp_df_1.iloc[:,1:2]
new_df
# Out:
#                                        Translated_Review
# 0      I like eat delicious food. That's I'm cooking ...
# 1        This help eating healthy exercise regular basis
# 3             Works great especially going grocery store
# 4                                           Best idea us
# 5                                               Best way
# ...                                                  ...
# 64222  Most ads older many agents ..not much owner po...
# 64223  If photos posted portal load, fit purpose. I'm...
# 64226  Dumb app, I wanted post property rent give opt...
# 64227  I property business got link SMS happy perform...
# 64230  Useless app, I searched flats kondapur, Hydera...
#
# [37427 rows x 1 columns]

# %%
count=0
for item in new_df['Translated_Review']:
  count=count+len(item.split())
print("Total number of words in Translated_Review=",count)
print("Total number of words in Translated_Review=",round(count/37427),'words.')
# Out:
# Total number of words in Translated_Review= 686808
# Total number of words in Translated_Review= 18 words.

# %%
playapp_df_1.dropna(axis=0, how='all', subset=['Sentiment'], inplace=True)
playapp_df_1
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# 64222  Most ads older many agents ..not much owner po...  Positive
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 3                0.400000                0.875000
# 4                1.000000                0.300000
# 5                1.000000                0.300000
# ...                   ...                     ...
# 64222            0.173333                0.486667
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000
#
# [37427 rows x 5 columns]

# %%
count=0
for word in playapp_df_1['Sentiment']:
  if word=='Positive':
    count=count+1
print("Total number of positive sentiment in sentiment=",count)
# Out:
# Total number of positive sentiment in sentiment= 23998

# %%
count_sentiment = playapp_df_1.groupby(["Sentiment"])["Sentiment"].count()
count_sentiment
# Out:
# Sentiment
# Negative     8271
# Neutral      5158
# Positive    23998
# Name: Sentiment, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10, 5)

# %%
plt.plot(count_sentiment)
plt.title('Different user sentiment')
plt.ylabel('total no. of different user sentiment')
plt.xlabel('Sentiment')
# Out:
# Text(0.5, 0, 'Sentiment')

# %%
count_sentiment.plot(kind='bar')
plt.title('Different user sentiment')
plt.ylabel('total no. of different user sentiment')
plt.xlabel('Sentiment')
# Out:
# Text(0.5, 0, 'Sentiment')

# %%
merged_RJ_df = pd.merge(playapp_df, playapp_df_1, how='left',left_on=['App'],right_on='App')
merged_RJ_df
# Out:
#                                                   App             Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                 Coloring book moana       ART_AND_DESIGN
# 2                                 Coloring book moana       ART_AND_DESIGN
# 3                                 Coloring book moana       ART_AND_DESIGN
# 4                                 Coloring book moana       ART_AND_DESIGN
# ...                                               ...                  ...
# 82212                                Sya9a Maroc - FR               FAMILY
# 82213                Fr. Mike Schmitz Audio Teachings               FAMILY
# 82214                          Parkinson Exercices FR              MEDICAL
# 82215                   The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 82216   iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         3.9     967                 14M     500,000+  Free     0
# 3         3.9     967                 14M     500,000+  Free     0
# 4         3.9     967                 14M     500,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 82212     4.5      38                 53M       5,000+  Free     0
# 82213     5.0       4                3.6M         100+  Free     0
# 82214     NaN       3                9.5M       1,000+  Free     0
# 82215     4.5     114  Varies with device       1,000+  Free     0
# 82216     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone  Art & Design;Pretend Play  January 15, 2018
# 3           Everyone  Art & Design;Pretend Play  January 15, 2018
# 4           Everyone  Art & Design;Pretend Play  January 15, 2018
# ...              ...                        ...               ...
# 82212       Everyone                  Education     July 25, 2017
# 82213       Everyone                  Education      July 6, 2018
# 82214       Everyone                    Medical  January 20, 2017
# 82215     Mature 17+          Books & Reference  January 19, 2015
# 82216       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver  year  \
# 0                   1.0.0        4.0.3 and up  2018
# 1                   2.0.0        4.0.3 and up  2018
# 2                   2.0.0        4.0.3 and up  2018
# 3                   2.0.0        4.0.3 and up  2018
# 4                   2.0.0        4.0.3 and up  2018
# ...                   ...                 ...   ...
# 82212                1.48          4.1 and up  2017
# 82213                 1.0          4.1 and up  2018
# 82214                 1.0          2.2 and up  2017
# 82215  Varies with device  Varies with device  2015
# 82216  Varies with device  Varies with device  2018
#
#                                        Translated_Review Sentiment  \
# 0                                                    NaN       NaN
# 1      A kid's excessive ads. The types ads allowed a...  Negative
# 2                                             It bad >:(  Negative
# 3                                                   like   Neutral
# 4                               I love colors inspyering  Positive
# ...                                                  ...       ...
# 82212                                                NaN       NaN
# 82213                                                NaN       NaN
# 82214                                                NaN       NaN
# 82215                                                NaN       NaN
# 82216                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                     NaN                     NaN
# 1                  -0.250                1.000000
# 2                  -0.725                0.833333
# 3                   0.000                0.000000
# 4                   0.500                0.600000
# ...                   ...                     ...
# 82212                 NaN                     NaN
# 82213                 NaN                     NaN
# 82214                 NaN                     NaN
# 82215                 NaN                     NaN
# 82216                 NaN                     NaN
#
# [82217 rows x 18 columns]

# %%
merged_RJ_df.dropna(axis=0, how='all', subset=['Sentiment_Polarity'], inplace=True)
merged_RJ_df
# Out:
#                                       App        Category  Rating Reviews  \
# 1                     Coloring book moana  ART_AND_DESIGN     3.9     967
# 2                     Coloring book moana  ART_AND_DESIGN     3.9     967
# 3                     Coloring book moana  ART_AND_DESIGN     3.9     967
# 4                     Coloring book moana  ART_AND_DESIGN     3.9     967
# 5                     Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                                   ...             ...     ...     ...
# 82092  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 82093  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 82094  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 82095  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 82096  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
#
#        Size    Installs  Type Price Content Rating                     Genres  \
# 1       14M    500,000+  Free     0       Everyone  Art & Design;Pretend Play
# 2       14M    500,000+  Free     0       Everyone  Art & Design;Pretend Play
# 3       14M    500,000+  Free     0       Everyone  Art & Design;Pretend Play
# 4       14M    500,000+  Free     0       Everyone  Art & Design;Pretend Play
# 5       14M    500,000+  Free     0       Everyone  Art & Design;Pretend Play
# ...     ...         ...   ...   ...            ...                        ...
# 82092  4.0M  1,000,000+  Free     0       Everyone              Communication
# 82093  4.0M  1,000,000+  Free     0       Everyone              Communication
# 82094  4.0M  1,000,000+  Free     0       Everyone              Communication
# 82095  4.0M  1,000,000+  Free     0       Everyone              Communication
# 82096  4.0M  1,000,000+  Free     0       Everyone              Communication
#
#            Last Updated Current Ver   Android Ver  year  \
# 1      January 15, 2018       2.0.0  4.0.3 and up  2018
# 2      January 15, 2018       2.0.0  4.0.3 and up  2018
# 3      January 15, 2018       2.0.0  4.0.3 and up  2018
# 4      January 15, 2018       2.0.0  4.0.3 and up  2018
# 5      January 15, 2018       2.0.0  4.0.3 and up  2018
# ...                 ...         ...           ...   ...
# 82092      July 6, 2018         5.2    5.0 and up  2018
# 82093      July 6, 2018         5.2    5.0 and up  2018
# 82094      July 6, 2018         5.2    5.0 and up  2018
# 82095      July 6, 2018         5.2    5.0 and up  2018
# 82096      July 6, 2018         5.2    5.0 and up  2018
#
#                                        Translated_Review Sentiment  \
# 1      A kid's excessive ads. The types ads allowed a...  Negative
# 2                                             It bad >:(  Negative
# 3                                                   like   Neutral
# 4                               I love colors inspyering  Positive
# 5                                                 I hate  Negative
# ...                                                  ...       ...
# 82092  Nice broser slow browsing speed... make 8mbps ...  Positive
# 82093  The thing I found missing simple bookmark draw...  Positive
# 82094  Great Relief unwanted pop ups showing up. What...  Positive
# 82095  Hoped found new go-to; LOVE Firefox PC. Aside ...  Positive
# 82096  Moment I turned YouTube video I got ad. That's...   Neutral
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 1               -0.250000                1.000000
# 2               -0.725000                0.833333
# 3                0.000000                0.000000
# 4                0.500000                0.600000
# 5               -0.800000                0.900000
# ...                   ...                     ...
# 82092            0.100000                0.492308
# 82093            0.225000                0.426786
# 82094            0.650000                0.625000
# 82095            0.345455                0.484848
# 82096            0.000000                0.000000
#
# [72605 rows x 18 columns]

# %%
a=merged_RJ_df[ (merged_RJ_df['Sentiment_Polarity'] > 0.5) & (merged_RJ_df['Sentiment_Subjectivity'] > 0.5)].reset_index(drop=True)
a
# Out:
#                                      App        Category  Rating Reviews  \
# 0                    Coloring book moana  ART_AND_DESIGN     3.9     967
# 1                    Coloring book moana  ART_AND_DESIGN     3.9     967
# 2                    Coloring book moana  ART_AND_DESIGN     3.9     967
# 3                    Coloring book moana  ART_AND_DESIGN     3.9     967
# 4                    Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                                  ...             ...     ...     ...
# 8304  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 8305  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 8306  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 8307  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
# 8308  Firefox Focus: The privacy browser   COMMUNICATION     4.4   36981
#
#       Size    Installs  Type Price Content Rating                     Genres  \
# 0      14M    500,000+  Free     0       Everyone  Art & Design;Pretend Play
# 1      14M    500,000+  Free     0       Everyone  Art & Design;Pretend Play
# 2      14M    500,000+  Free     0       Everyone  Art & Design;Pretend Play
# 3      14M    500,000+  Free     0       Everyone  Art & Design;Pretend Play
# 4      14M    500,000+  Free     0       Everyone  Art & Design;Pretend Play
# ...    ...         ...   ...   ...            ...                        ...
# 8304  4.0M  1,000,000+  Free     0       Everyone              Communication
# 8305  4.0M  1,000,000+  Free     0       Everyone              Communication
# 8306  4.0M  1,000,000+  Free     0       Everyone              Communication
# 8307  4.0M  1,000,000+  Free     0       Everyone              Communication
# 8308  4.0M  1,000,000+  Free     0       Everyone              Communication
#
#           Last Updated Current Ver   Android Ver  year  \
# 0     January 15, 2018       2.0.0  4.0.3 and up  2018
# 1     January 15, 2018       2.0.0  4.0.3 and up  2018
# 2     January 15, 2018       2.0.0  4.0.3 and up  2018
# 3     January 15, 2018       2.0.0  4.0.3 and up  2018
# 4     January 15, 2018       2.0.0  4.0.3 and up  2018
# ...                ...         ...           ...   ...
# 8304      July 6, 2018         5.2    5.0 and up  2018
# 8305      July 6, 2018         5.2    5.0 and up  2018
# 8306      July 6, 2018         5.2    5.0 and up  2018
# 8307      July 6, 2018         5.2    5.0 and up  2018
# 8308      July 6, 2018         5.2    5.0 and up  2018
#
#                                       Translated_Review Sentiment  \
# 0                                            Good great  Positive
# 1                                        This beautiful  Positive
# 2                                               Perfect  Positive
# 3                                            Good great  Positive
# 4                                        This beautiful  Positive
# ...                                                 ...       ...
# 8304  Great Relief unwanted pop ups showing up. What...  Positive
# 8305  Great app! Love addition search page. Can cons...  Positive
# 8306  Best browser... If privacy concern please brow...  Positive
# 8307  Firefox Focus mobile browsers be. It 'feels' f...  Positive
# 8308  Great Relief unwanted pop ups showing up. What...  Positive
#
#       Sentiment_Polarity  Sentiment_Subjectivity
# 0               0.750000                0.675000
# 1               0.850000                1.000000
# 2               1.000000                1.000000
# 3               0.750000                0.675000
# 4               0.850000                1.000000
# ...                  ...                     ...
# 8304            0.650000                0.625000
# 8305            0.550000                0.518750
# 8306            0.535119                0.714286
# 8307            0.600000                0.900000
# 8308            0.650000                0.625000
#
# [8309 rows x 18 columns]

# %%
b=a.drop(['year','Rating','Reviews','Size','Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver','Translated_Review','Sentiment'],axis=1)
c=b.head(20)

# %%
c.plot(x='Category', y='Sentiment_Polarity',figsize=(10,5),kind="bar")
